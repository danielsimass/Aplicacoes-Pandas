# %% [markdown]
# # Relatório de análise IV

# %%
import pandas as pd

# %%
dados = pd.read_csv("dados/aluguel.csv", sep= ";")

# %% [markdown]
# ## Selecionando somente os apartamentos

# %%
selecao_apto = dados['Tipo'] == 'Apartamento'

# %%
dados_apto = dados[selecao_apto]
dados_apto.head(10)
# Out:
#            Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 3   Apartamento                   Centro        1      0       0    15
# 4   Apartamento             Higienópolis        1      0       0    48
# 5   Apartamento             Vista Alegre        3      1       0    70
# 6   Apartamento                 Cachambi        2      0       0    50
# 10  Apartamento                   Centro        1      0       0    36
# 11  Apartamento                   Grajaú        2      1       0    70
# 12  Apartamento      Lins de Vasconcelos        3      1       1    90
# 13  Apartamento               Copacabana        1      0       1    40
# 15  Apartamento               Copacabana        4      3       1   243
# 19  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
#
#       Valor  Condominio   IPTU
# 3     800.0       390.0   20.0
# 4     800.0       230.0    NaN
# 5    1200.0         NaN    NaN
# 6    1300.0       301.0   17.0
# ...

# %%
dados_apto.index = range(dados_apto.shape[0])
dados_apto
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                Centro        1      0       0    15
# 1      Apartamento          Higienópolis        1      0       0    48
# 2      Apartamento          Vista Alegre        3      1       0    70
# 3      Apartamento              Cachambi        2      0       0    50
# 4      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 19527  Apartamento        Vila Valqueire        2      0       0    52
# 19528  Apartamento                 Méier        2      0       0    70
# 19529  Apartamento           Jacarepaguá        3      1       2    78
# 19530  Apartamento  São Francisco Xavier        2      1       0    48
# 19531  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0       800.0       390.0  20.0
# 1       800.0       230.0   NaN
# ...

# %%
# São 19532 apartamentos no banco de dados

# %%
# Exportando o DataFrame somente com os apartamentos
dados_apto.to_csv('dados/aluguel_apto.csv', sep=';', index=False)

# %% [markdown]
# ## Selecionando 'Casa', 'Casa de Condominio' e 'Casa de Vila'

# %%
selecao2 = dados['Tipo'].isin(['Casa', 'Casa de Condomínio', 'Casa de Vila'])

# %%
dados_casa_condominio_vila = dados[selecao2]

# %%
dados_casa_condominio_vila.index = range(dados_casa_condominio_vila.shape[0])
dados_casa_condominio_vila
# Out:
#                     Tipo                   Bairro  Quartos  Vagas  Suites  \
# 0                   Casa          Jardim Botânico        2      0       1
# 1     Casa de Condomínio          Barra da Tijuca        5      4       5
# 2     Casa de Condomínio                    Ramos        2      2       0
# 3     Casa de Condomínio                  Taquara        3      1       1
# 4     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                  ...                      ...      ...    ...     ...
# 2207  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 2208                Casa            Bento Ribeiro        2      1       0
# 2209  Casa de Condomínio          Barra da Tijuca        3      5       3
# 2210                Casa                   Centro        5      0       1
# 2211  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#       Area    Valor  Condominio    IPTU
# ...

# %%
# São 2212 imóveis do tipo Casa, Casa de Condomínio e Casa de Vila

# %%
# Exportando o DataFrame

# %%
dados_casa_condominio_vila.to_csv('dados/aluguel_casa_condominio_vila.csv', sep=';', index=False)

# %% [markdown]
# ## Selecionandoos imóveis com área maior que 60 e menor que 100

# %%
selecao3 = (dados['Area']>= 60) & (dados['Area'] <= 100)
dados_area = dados[selecao3]
dados_area.index = range(dados_area.shape[0])
dados_area
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0                    Casa           Jardim Botânico        2      0       1
# 1             Apartamento              Vista Alegre        3      1       0
# 2      Casa de Condomínio                     Ramos        2      2       0
# 3             Apartamento                    Grajaú        2      1       0
# 4             Apartamento       Lins de Vasconcelos        3      1       1
# ...                   ...                       ...      ...    ...     ...
# 10182         Apartamento  Recreio dos Bandeirantes        3      2       1
# 10183         Apartamento                    Leblon        3      0       1
# 10184         Apartamento                     Méier        2      0       0
# 10185         Apartamento               Jacarepaguá        3      1       2
# 10186         Apartamento                    Leblon        2      0       0
#
#        Area   Valor  Condominio   IPTU
# ...

# %%
# São 10187 imóveis com área maior que 60 e menor que 100

# %% [markdown]
# ## Selecionando imóveis com pelo menos 4 quartos e aluguel menor que R$ 2.000,00

# %%
dados4 = dados[(dados['Quartos'] <= 4) & (dados['Valor'] < 2000)]

# %%
dados4.shape[0]
# Out:
# 11856

# %%
#São 11856 Imóveis dentro desses padrões
